# %% [markdown]
# ### Project Setup

# %%
""" Imports """
import pandas as pd
from pathlib import Path

# %%
""" Constants """
DATA_PATH = Path('../data/kagle_telco_customer_churn_data.csv')

# %% [markdown]
# ## Bronze Layer
#
# Raw data source: Telco Customer Churn dataset from Kaggle.
# The original CSV serves as the bronze layer — no transformations applied.
